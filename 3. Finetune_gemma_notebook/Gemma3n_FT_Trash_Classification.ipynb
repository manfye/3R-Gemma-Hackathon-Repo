jpg
#   inflating: Garbage_classification_benchmark/single_material_image/trash/trash_134.jpg
#   inflating: Garbage_classification_benchmark/single_material_image/trash/trash_136.jpg

# %% [markdown]
# ### Installation

# %%
# %pip install unsloth
# Out:
# Collecting unsloth
#   Downloading unsloth-2025.7.11-py3-none-any.whl.metadata (47 kB)
# Collecting unsloth_zoo>=2025.7.11 (from unsloth)
#   Downloading unsloth_zoo-2025.7.11-py3-none-any.whl.metadata (8.1 kB)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.31.post1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.1 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.4.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: packaging in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from unsloth) (25.0)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.9.27-py3-none-any.whl.metadata (11 kB)
# Collecting transformers!=4.47.0,!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,>=4.51.3 (from unsloth)
#   Downloading transformers-4.54.1-py3-none-any.whl.metadata (41 kB)
# Collecting datasets<4.0.0,>=3.4.1 (from unsloth)
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Collecting sentencepiece>=0.2.0 (from unsloth)
#   Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting tqdm (from unsloth)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: psutil in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from unsloth) (5.9.1)
# Requirement already satisfied: wheel>=0.42.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from unsloth) (0.45.1)
# Requirement already satisfied: numpy in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from unsloth) (2.2.6)
# Collecting accelerate>=0.34.1 (from unsloth)
#   Downloading accelerate-1.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting trl!=0.15.0,!=0.19.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.20.0-py3-none-any.whl.metadata (11 kB)
# Collecting peft!=0.11.0,>=0.7.1 (from unsloth)
#   Downloading peft-0.17.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: protobuf in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from unsloth) (6.31.1)
# Collecting huggingface_hub>=0.34.0 (from unsloth)
#   Downloading huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Collecting hf_transfer (from unsloth)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting diffusers (from unsloth)
#   Downloading diffusers-0.34.0-py3-none-any.whl.metadata (20 kB)
# Collecting torchvision (from unsloth)
#   Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from datasets<4.0.0,>=3.4.1->unsloth) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from datasets<4.0.0,>=3.4.1->unsloth) (20.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<4.0.0,>=3.4.1->unsloth)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from datasets<4.0.0,>=3.4.1->unsloth) (2.3.1)
# Requirement already satisfied: requests>=2.32.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from datasets<4.0.0,>=3.4.1->unsloth) (2.32.4)
# Collecting xxhash (from datasets<4.0.0,>=3.4.1->unsloth)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets<4.0.0,>=3.4.1->unsloth)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml>=5.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from datasets<4.0.0,>=3.4.1->unsloth) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (3.12.14)
# Collecting safetensors>=0.4.3 (from accelerate>=0.34.1->unsloth)
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (1.20.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (4.14.1)
# Requirement already satisfied: idna>=2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<4.0.0,>=3.4.1->unsloth) (3.10)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub>=0.34.0->unsloth)
#   Downloading hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from requests>=2.32.2->datasets<4.0.0,>=3.4.1->unsloth) (2025.7.9)
# Collecting sympy>=1.13.3 (from torch>=2.4.0->unsloth)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.4.0->unsloth)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from triton>=3.0.0->unsloth) (78.1.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.4.0->unsloth)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting regex!=2019.12.17 (from transformers!=4.47.0,!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,>=4.51.3->unsloth)
#   Downloading regex-2025.7.34-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers!=4.47.0,!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,>=4.51.3->unsloth)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting cut_cross_entropy (from unsloth_zoo>=2025.7.11->unsloth)
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting pillow (from unsloth_zoo>=2025.7.11->unsloth)
#   Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting msgspec (from unsloth_zoo>=2025.7.11->unsloth)
#   Downloading msgspec-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: importlib_metadata in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from diffusers->unsloth) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from importlib_metadata->diffusers->unsloth) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from jinja2->torch>=2.4.0->unsloth) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pandas->datasets<4.0.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pandas->datasets<4.0.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from pandas->datasets<4.0.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets<4.0.0,>=3.4.1->unsloth) (1.17.0)
# Collecting docstring-parser>=0.15 (from tyro->unsloth)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=11.1.0 (from tyro->unsloth)
#   Downloading rich-14.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting typeguard>=4.0.0 (from tyro->unsloth)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth) (0.1.2)
# Downloading unsloth-2025.7.11-py3-none-any.whl (299 kB)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Downloading accelerate-1.9.0-py3-none-any.whl (367 kB)
# Downloading huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.8/558.8 kB 14.0 MB/s eta 0:00:00
# Downloading hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 33.9 MB/s eta 0:00:00
# Downloading peft-0.17.0-py3-none-any.whl (503 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.9 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 21.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 83.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 104.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 138.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 42.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 60.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 114.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 123.1 MB/s eta 0:00:0000:01
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 118.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 114.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 119.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 105.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 107.1 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 63.4 MB/s eta 0:00:0000:0100:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 131.4 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 20.7 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.54.1-py3-none-any.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 84.0 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 59.5 MB/s eta 0:00:00
# Downloading regex-2025.7.34-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (789 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 789.8/789.8 kB 33.0 MB/s eta 0:00:00
# Downloading trl-0.20.0-py3-none-any.whl (504 kB)
# Downloading unsloth_zoo-2025.7.11-py3-none-any.whl (166 kB)
# Downloading xformers-0.0.31.post1-cp39-abi3-manylinux_2_28_x86_64.whl (117.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 MB 105.2 MB/s eta 0:00:0000:0100:01
# Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 39.7 MB/s eta 0:00:00:00:0100:01
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading diffusers-0.34.0-py3-none-any.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 3.0 MB/s eta 0:00:00eta 0:00:01
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 3.2 MB/s eta 0:00:00eta 0:00:01
# Downloading msgspec-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.1 MB/s eta 0:00:00
# Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 137.5 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 135.3 MB/s eta 0:00:00
# Downloading tyro-0.9.27-py3-none-any.whl (129 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading rich-14.1.0-py3-none-any.whl (243 kB)
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
# Installing collected packages: sentencepiece, nvidia-cusparselt-cu12, mpmath, xxhash, typeguard, triton, tqdm, sympy, shtab, safetensors, regex, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, msgspec, hf-xet, hf_transfer, fsspec, docstring-parser, dill, rich, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, huggingface_hub, tyro, tokenizers, nvidia-cusolver-cu12, diffusers, transformers, torch, xformers, torchvision, datasets, cut_cross_entropy, bitsandbytes, accelerate, trl, peft, unsloth_zoo, unsloth
#   Attempting uninstall: fsspec╺━━━━━━━━━━━━━━━━━━━━━ 23/50 [hf-xet]x]blas-cu12]u12]
#     Found existing installation: fsspec 2025.5.1━━━━━━━━━━━━━━ 23/50 [hf-xet]
#     Uninstalling fsspec-2025.5.1:━━━━━━━━━━━━━━━━━━━━━ 23/50 [hf-xet]
#       Successfully uninstalled fsspec-2025.5.1━━━━━━━━━━━━━━━━ 23/50 [hf-xet]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50/50 [unsloth][unsloth][unsloth_zoo]]ropy]12]
# Successfully installed accelerate-1.9.0 bitsandbytes-0.46.1 cut_cross_entropy-25.1.1 datasets-3.6.0 diffusers-0.34.0 dill-0.3.8 docstring-parser-0.17.0 fsspec-2025.3.0 hf-xet-1.1.5 hf_transfer-0.1.9 huggingface_hub-0.34.3 mpmath-1.3.0 msgspec-0.19.0 multiprocess-0.70.16 networkx-3.4.2 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 peft-0.17.0 pillow-11.3.0 regex-2025.7.34 rich-14.1.0 safetensors-0.5.3 sentencepiece-0.2.0 shtab-1.7.2 sympy-1.14.0 tokenizers-0.21.4 torch-2.7.1 torchvision-0.22.1 tqdm-4.67.1 transformers-4.54.1 triton-3.3.1 trl-0.20.0 typeguard-4.4.4 tyro-0.9.27 unsloth-2025.7.11 unsloth_zoo-2025.7.11 xformers-0.0.31.post1 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%capture
# Install latest transformers for Gemma 3N
# %pip install --no-deps --upgrade timm # Only for Gemma 3N

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastVisionModel # FastLanguageModel for LLMs
import torch

model, tokenizer = FastVisionModel.from_pretrained(
    "unsloth/gemma-3n-E4B-it", # or "unsloth/gemma-3n-E2B-it"
    load_in_4bit = True, # Use 4bit to reduce memory use. False for 16bit LoRA.
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for long context
    # token = ""
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.7.11: Fast Gemma3N patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA A100 80GB PCIe. Num GPUs = 1. Max memory: 79.151 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.1+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.3.1
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.31.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Gemma3N does not support SDPA - switching to eager!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.
#
# **[NEW]** We also support finetuning ONLY the vision part of the model, or ONLY the language part. Or you can select both! You can also select to finetune the attention or the MLP layers!

# %%
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = True, # False if not finetuning vision layers
    finetune_language_layers   = True, # False if not finetuning language layers
    finetune_attention_modules = True, # False if not finetuning attention layers
    finetune_mlp_modules       = True, # False if not finetuning MLP layers

    r = 16,           # The larger, the higher the accuracy, but might overfit
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    # target_modules = "all-linear", # Optional now! Can specify a list if needed
)
# Out:
# Unsloth: Making `model.base_model.model.model.language_model` require gradients

# %%
import torch._dynamo.config
torch._dynamo.config.recompile_limit = 512

# %% [markdown]
# ### Inference before FT

# %% [markdown]
# Before we do any finetuning, maybe the vision model already knows how to analyse the images? Let's check if this is the case!
#
# We use Gemma 3N's recommended settings of `temperature = 1.0, top_p = 0.95, top_k = 64`

# %%
from PIL import Image

FastVisionModel.for_inference(model) # Enable for inference!

PROMPT_FOR_VISION = (
    "You are a garbage classification assistant. Based on the image, identify and classify all distinct parts of the object. "
    "For each part, determine the type of garbage from the following options: A: Cardboard, B: Glass, C: Metal, D: Paper, E: Plastic, F: Trash. "
    "Your response must be in a JSON format. The JSON should contain a single key, 'material', which holds an array of objects. "
    "Each object in the array must have two keys: 'part_name' (a brief description of the item) and 'answer' (the classification from the provided options, in the format 'A: Cardboard'). "
    "If the image contains multiple distinct parts made of different materials, list each part as a separate object in the 'material' array. "
    "For example, if the image shows a paper coffee cup with a plastic lid, you should output two separate objects in the array. "
    "The cup should be classified as 'D: Paper' and the lid as 'E: Plastic'. "
    "If a part is not classified into a specific category, consider it as 'F: Trash'."
)

image_path = "WhatsApp Image 2025-08-01 at 23.50.15_38d0037a.jpg"

image = Image.open(image_path).convert("RGB").resize((512, 512))

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": PROMPT_FOR_VISION}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
# Convert the grayscale image to RGB
if image.mode != "RGB":
    image = image.convert("RGB")

inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.0, top_p = 0.95, top_k = 64)
# Out:
# ```json
# {
#   "material": [
#     {
#       "part_name": "Cup body",
#       "answer": "A: Cardboard"
#     },
#     {
#       "part_name": "Lid",
#       "answer": "E: Plastic"
#     }
#   ]
# }
# ```<end_of_turn>

# %% [markdown]
# ## Data Preparation for Trash Classification

# %%
import pandas as pd
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig
from datasets import Dataset, DatasetDict, Features, Value, Sequence, Image as DatasetsImage

# %%
DATASET_CSV_PATH = os.path.abspath("Garbage_classification_benchmark/final_comprehensive_ground_truth_dataset.csv")
IMAGE_ROOT_DIR = "Garbage_classification_benchmark"

PROMPT_FOR_VISION = (
    "You are a garbage classification assistant. Based on the image, identify and classify all distinct parts of the object. "
    "For each part, determine the type of garbage from the following options: A: Cardboard, B: Glass, C: Metal, D: Paper, E: Plastic, F: Trash. "
    "Your response must be in a JSON format. The JSON should contain a single key, 'material', which holds an array of objects. "
    "Each object in the array must have two keys: 'part_name' (a brief description of the item) and 'answer' (the classification from the provided options, in the format 'A: Cardboard'). "
    "If the image contains multiple distinct parts made of different materials, list each part as a separate object in the 'material' array. "
    "For example, if the image shows a paper coffee cup with a plastic lid, you should output two separate objects in the array. "
    "The cup should be classified as 'D: Paper' and the lid as 'E: Plastic'. "
    "If a part is not classified into a specific category, consider it as 'F: Trash'."
)

# %% [markdown]
# ### Read Dataset and Split the Single Material Classes

# %%
# Load the dataset
df = pd.read_csv(DATASET_CSV_PATH)

# Step 1: Split by material type
df_single = df[df["material_type"] == "single"].copy()
df_multi = df[df["material_type"] == "multiple"].copy()

# %%
# Step 2: Stratified train-test split on single-material by primary_class
single_train, single_test = train_test_split(
    df_single,
    test_size=0.3,
    stratify=df_single["primary_class"],
    random_state=42
)

# Step 3: Random train-test split on multiple-material
multi_train, multi_test = train_test_split(
    df_multi,
    test_size=0.3,
    random_state=42,
    shuffle=True
)

# Step 4: Add split labels
single_train["dataset_split"] = "train"
single_test["dataset_split"] = "test"
multi_train["dataset_split"] = "train"
multi_test["dataset_split"] = "test"

# Step 5: Combine train and test
train_split = pd.concat([single_train, multi_train], ignore_index=True)
test_split = pd.concat([single_test, multi_test], ignore_index=True)

# Step 6: Save to CSV
train_split.to_csv("train_split.csv", index=False)
test_split.to_csv("test_split.csv", index=False)

# %% [markdown]
# ### Function for formatting training data for Unsloth

# %%
# Format example with PIL.Image
def format_data_for_unsloth(example):
    try:
        relative_path = example["relative_path"]
        full_path = os.path.normpath(os.path.join(IMAGE_ROOT_DIR, relative_path))

        print(f"Processing image: {full_path}")
        image = Image.open(full_path).convert("RGB").resize((512, 512))

        assistant_response = example["chatgpt4o_answer"]

        return {
            "messages": [
                {
                    "role": "user",
                    "content": [
                        {"type": "image", "image": image},
                        {"type": "text", "text": PROMPT_FOR_VISION},
                    ],
                },
                {
                    "role": "assistant",
                    "content": [
                        {"type": "text", "text": assistant_response},
                    ],
                },
            ]
        }

    except (FileNotFoundError, UnidentifiedImageError, OSError, KeyError) as e:
        print(f"❌ Skipping due to error: {e}")
        return None

# %%
processed_data = []

# Iterate only over the training set
for _, row in train_split.iterrows():
    result = format_data_for_unsloth(row)
    if result is not None:
        processed_data.append(result)
# Out:
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_150.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_001.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_129.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_090.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_161.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_131.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_268.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_141.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/trash_026.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_102.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_259.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_235.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological28.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_045.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_292.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_132.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_094.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_021.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_199.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_117.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological42.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_231.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_295.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_046.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_299.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_070.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_172.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_203.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_245.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_167.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_202.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_262.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_043.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological54.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_181.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_071.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_220.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_111.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_139.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_246.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_005.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_093.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_015.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_113.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_034.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_174.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/trash_098.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological157.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological106.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_249.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_036.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_020.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_051.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_176.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_057.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_106.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_218.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_119.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_045.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_151.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_234.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_149.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_240.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_072.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_127.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_003.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_133.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_255.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_004.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_275.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_228.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_285.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_049.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_209.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_241.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_016.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_174.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological115.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological148.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_038.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological69.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_047.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_115.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_021.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_040.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_052.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/trash_081.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_111.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_286.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_252.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_152.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_265.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_185.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_012.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_115.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_272.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_186.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_033.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_192.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_091.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_273.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_132.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_287.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_060.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_007.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_061.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_121.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_143.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_279.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_243.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_172.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_054.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_157.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_234.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_232.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_168.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_089.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_060.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_202.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_218.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_205.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_300.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_137.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_111.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_152.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/trash_062.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_222.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_138.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological95.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_165.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_223.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_070.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_037.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_239.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/trash_029.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_205.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological138.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_242.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_123.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_021.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_041.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/trash/biological134.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass_163.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_149.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/metal/metal_058.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_191.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_296.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_088.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_296.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/cardboard/cardboard_150.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/plastic/plastic_153.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/paper/paper_208.jpg
# Processing image: Garbage_classification_benchmark/single_material_image/glass/glass
jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_157.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_255.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_159.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_078.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_098.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_277.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_270.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_106.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_051.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_051.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_paper/metal_038.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_012.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_232.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_093.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_098.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_237.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_086.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_157.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_plastic/plastic_048.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_152.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_065.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_018.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_192.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_120.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_255.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_058.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_043.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_179.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_079.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_090.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_231.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/biological140.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_paper/cardboard_044.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_253.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_189.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_259.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_081.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/trash_039.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_197.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_025.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_087.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_106.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_072.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_243.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_218.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_252.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_277.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_297.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/biological81.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_166.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_006.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_120.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/biological49.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_250.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_080.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_110.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_117.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_paper/paper_140.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_135.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_155.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_115.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_003.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_024.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_018.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_225.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_265.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_042.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_176.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_288.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_151.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_065.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_plastic/trash_124.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_plastic/plastic_015.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_221.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_269.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_276.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_021.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_293.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_253.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_146.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_136.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_272.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_213.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_049.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_212.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_009.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_010.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_023.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_264.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_102.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_073.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/paper_089.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_001.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_269.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_056.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_297.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_144.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_091.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_192.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_paper/cardboard_052.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_082.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_036.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/paper_284.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_231.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_157.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_061.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_170.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_158.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_022.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_017.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_056.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_181.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_066.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_097.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_164.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_053.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_026.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_208.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_131.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_139.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_296.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_132.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_286.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_093.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_222.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_metal/glass_075.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_008.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_106.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_062.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_plastic/glass_032.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_188.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_300.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_257.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_128.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_037.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_275.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_155.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_278.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_080.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_055.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/paper_trash/trash_032.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_133.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/trash_135.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/cardboard_trash/cardboard_040.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/metal_trash/metal_289.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_011.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_101.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/plastic_trash/plastic_175.jpg
# Processing image: Garbage_classification_benchmark/multiple_material_image/glass_trash/glass_086.jpg

# %%
train_data, val_data = train_test_split(processed_data, test_size=0.2, random_state=42)

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!
#
# We use our new `UnslothVisionDataCollator` which will help in our vision finetuning setup.

# %%
from unsloth.trainer import UnslothVisionDataCollator
from transformers import EarlyStoppingCallback
from trl import SFTTrainer, SFTConfig

FastVisionModel.for_training(model) # Enable for training!

early_stopping = EarlyStoppingCallback(
    early_stopping_patience=3,  # Number of evaluations with no improvement before stopping
    early_stopping_threshold=0.0  # Minimum improvement to be considered as an improvement
)

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = UnslothVisionDataCollator(model, tokenizer, resize=512), # Must use!
    train_dataset = train_data, # Use the list of processed samples
    eval_dataset = val_data, # Also use for evaluation if desired
    args = SFTConfig(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        # gradient_checkpointing = True,  # reduces VRAM usage at the cost of slightly longer training time.
        warmup_steps = 5,
        # max_steps = 100,
        num_train_epochs = 3, # Set this instead of max_steps for full training runs
        learning_rate = 5e-6,
        logging_steps = 1,
        save_strategy="steps",
        optim = "adamw_torch_fused", # "adamw_8bit"
        weight_decay = 0.01,
        lr_scheduler_type = "cosine", # or use "linear"
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",     # For Weights and Biases

        # MUST put the below items for vision finetuning:
        remove_unused_columns = False,
        dataset_text_field = "",
        dataset_kwargs = {"skip_prepare_dataset": True},
        max_length = 2048,
        
        eval_strategy="steps",
        eval_steps=50,                # Adjust as needed for how often to check eval loss
        save_total_limit=2,           # Optional: limit saved checkpoints
        load_best_model_at_end=True,  # Restore best model
        metric_for_best_model="eval_loss",  # Required for early stopping
        greater_is_better=False 
    ),
    callbacks=[early_stopping]
)

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100 80GB PCIe. Max memory = 79.151 GB.
# 9.795 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 992 | Num Epochs = 3 | Total steps = 372
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 38,420,480 of 7,888,398,672 (0.49% trained)
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='200' max='372' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/372 16:03 < 13:56, 0.21 it/s, Epoch 1/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.074200</td>
#       <td>2.312983</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.054600</td>
#       <td>2.314820</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.046300</td>
#       <td>2.319943</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.040600</td>
#       <td>2.321056</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Not an error, but Gemma3nForConditionalGeneration does not accept `num_items_in_batch`.
# Using gradient accumulation will be very slightly less accurate.
# Read more on gradient accumulation issues here: https://unsloth.ai/blog/gradient

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 1062.4979 seconds used for training.
# 17.71 minutes used for training.
# Peak reserved memory = 11.715 GB.
# Peak reserved memory for training = 1.92 GB.
# Peak reserved memory % of max memory = 14.801 %.
# Peak reserved memory for training % of max memory = 2.426 %.

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
import os

save_dir = "qizunlee/gemma3n_E4B_it_ft_3RGarbageClassification_merged"
os.makedirs(save_dir, exist_ok=True)  # Create directory if it doesn't exist

# %%
# Merge the LoRA adapter with the base model
model.push_to_hub_merged("qizunlee/gemma3n_E4B_it_ft_3RGarbageClassification_merged", tokenizer, token = "<TOKEN>")
# Out:
# No files have been modified since last commit. Skipping to prevent empty commit.
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   /tmp/tmpxu5gr_7q/tokenizer.model      : 100%|##########| 4.70MB / 4.70MB
#   /tmp/tmpxu5gr_7q/tokenizer.json       : 100%|##########| 33.4MB / 33.4MB
# No files have been modified since last commit. Skipping to prevent empty commit.
# Found HuggingFace hub cache directory: /home/azureuser/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00004.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Downloading safetensors index for unsloth/gemma-3n-e4b-it...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# No files have been modified since last commit. Skipping to prevent empty commit.
# Unsloth: Merging weights into 16bit:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...7q/model-00001-of-00004.safetensors:   2%|1         | 50.3MB / 3.08GB
# Unsloth: Merging weights into 16bit:  25%|██▌       | 1/4 [00:35<01:47, 35.90s/it]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...7q/model-00002-of-00004.safetensors:   2%|2         |  101MB / 4.97GB
# Unsloth: Merging weights into 16bit:  50%|█████     | 2/4 [01:20<01:22, 41.16s/it]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...7q/model-00003-of-00004.safetensors:   1%|1         | 66.5MB / 4.99GB
# Unsloth: Merging weights into 16bit:  75%|███████▌  | 3/4 [02:20<00:49, 49.52s/it]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.66G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...7q/model-00004-of-00004.safetensors:   0%|          | 36.1kB / 2.66GB
# Unsloth: Merging weights into 16bit: 100%|██████████| 4/4 [02:52<00:00, 43.14s/it]

# %%
# Merge the LoRA adapter with the base model
# model = model.merge_and_unload()

# Save the model (lora_adapter) locally
model.save_pretrained("gemma3n_E4B_it_ft_3RGarbageClassification")
tokenizer.save_pretrained("gemma3n_E4B_it_ft_3RGarbageClassification")

# Saving the model to HF
model.push_to_hub("qizunlee/gemma3n_E4B_it_ft_3RGarbageClassification",
                  token = "<TOKEN>")
tokenizer.push_to_hub("qizunlee/gemma3n_E4B_it_ft_3RGarbageClassification",
                      token = "<TOKEN>")
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...ification/adapter_model.safetensors:   0%|          | 9.88kB /  154MB
# Saved model to https://huggingface.co/qizunlee/gemma3n_E4B_it_ft_3RGarbageClassification
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...rbageClassification/tokenizer.model: 100%|##########| 4.70MB / 4.70MB
#   ...arbageClassification/tokenizer.json: 100%|##########| 33.4MB / 33.4MB

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
FastVisionModel.for_inference(model) # Enable for inference!

PROMPT_FOR_VISION = (
    "You are a garbage classification assistant. Based on the image, identify and classify all distinct parts of the object. "
    "For each part, determine the type of garbage from the following options: A: Cardboard, B: Glass, C: Metal, D: Paper, E: Plastic, F: Trash. "
    "Your response must be in a JSON format. The JSON should contain a single key, 'material', which holds an array of objects. "
    "Each object in the array must have two keys: 'part_name' (a brief description of the item) and 'answer' (the classification from the provided options, in the format 'A: Cardboard'). "
    "If the image contains multiple distinct parts made of different materials, list each part as a separate object in the 'material' array. "
    "For example, if the image shows a paper coffee cup with a plastic lid, you should output two separate objects in the array. "
    "The cup should be classified as 'D: Paper' and the lid as 'E: Plastic'. "
    "If a part is not classified into a specific category, consider it as 'F: Trash'."
)

image_path = "WhatsApp Image 2025-08-01 at 23.50.15_38d0037a.jpg"

image = Image.open(image_path).convert("RGB").resize((512, 512))

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": PROMPT_FOR_VISION}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
# Convert the grayscale image to RGB
if image.mode != "RGB":
    image = image.convert("RGB")

inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.0, top_p = 0.95, top_k = 64)

# %%
# Conversion to GGUF format
# https://huggingface.co/spaces/ggml-org/gguf-my-repo
